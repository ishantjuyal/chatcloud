# %%
from chatclouds import show, common

# %%
show("chat.txt")

# %%
common("chat.txt")
# Out:
# 20 most frequent used word in the chat are:
# 1. year
# 2. data
# 3. college
# 4. work
# 5. learn
# 6. things
# 7. guess
# 8. project
# 9. hanji
# 10. nice
# 11. intern
# 12. sem
# 13. wow
# 14. make
# 15. lot
# 16. cool
# 17. learning
# 18. projects
# 19. hehe
# 20. n
